# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/python_dersleri_2')
# !pwd
# Out:
# /content/drive/My Drive/python_dersleri_2

# %%
import sys

# %%
while True:
  try:
    gelen1 = float(input("Birinci Sayıyı Giriniz : "))
    gelen2 = float(input('İkinci Sayıyı Giriniz : '))

    if gelen1 > gelen2:
      print(f'{gelen1} Sayısı {gelen2} Sayısından Büyük')
    elif gelen1 < gelen2:
      print(f'{gelen1} Sayısı {gelen2} Sayısından Küçük')
    else:
      print(f'{gelen1} Sayısı {gelen2} Sayısına Eşit')
    break
  except ValueError:
    print('Lütfen Sayı Giriniz')
# Out:
# Birinci Sayıyı Giriniz : 12
# İkinci Sayıyı Giriniz : 14
# 12.0 Sayısı 14.0 Sayısından Küçük

# %%
while True:
  try:
    sayi = int(input("bir sayı giriniz :"))
    if sayi < 0:
      pritnt("negatif sayıların faktöriyeli hesaplannmaz")
    elif sayi == 0:
      sayi = 1
      print("sayınızın faktöriyeli 1")
    else:
      sonuc = 1
      while sayi > 1:
        sonuc *= sayi
        sayi -= 1
      print(sonuc)
    break
  except ValueError:
    print("lütfen sayı giriniz")
# Out:
# bir sayı giriniz :fgmdşg
# lütfen sayı giriniz
# bir sayı giriniz :98
# 9426890448883247745626185743057242473809693764078951663494238777294707070023223798882976159207729119823605850588608460429412647567360000000000000000000000

# %%
#Baslangic değeri negatif ise pozif değere dönüştürme
while True:
  try:
    baslangic = int(input("Başlangıç Değerini Giriniz :"))
    if baslangic < 0:
      baslangic = abs(baslangic)
      print(f"negatif bir değer girdiniz pozitif olarak alındı:{baslangic}")
    break
  except ValueError:
    print("lütfen sayı giriniz")

# ""  "" bitis değeri için
while True:
  try:
    bitis = int(input("Bitiş Değerini Giriniz :"))
    if bitis < 0:
      bitis = abs(bitis)
      print(f"negatif bir değer girdiniz pozitif olarak alındı:{bitis}")
    break
  except ValueError:
    print("lütfen sayı giriniz")
ciftsayilar = []
teksayilartoplam = 0
sayi = baslangic
while sayi <= bitis:
  if sayi % 2 == 0:
    ciftsayilar.append(sayi)
  else:
    teksayilartoplam += sayi
  sayi += 1

print(f"Çift Sayılar : {ciftsayilar}")
print(f"Tek Sayıların Toplamı : {teksayilartoplam}")
# Out:
# Başlangıç Değerini Giriniz :1
# Bitiş Değerini Giriniz :19
# Çift Sayılar : [2, 4, 6, 8, 10, 12, 14, 16, 18]
# Tek Sayıların Toplamı : 100

# %%
sesli = "aeıioöuüAEIİOÖUÜ"
kelime = input("Bir Kelime Giriniz :")
sesli_sayisi = 0
sessiz_sayisi = 0
for harf in kelime:
  if harf.isalpha():# sadce harfleri kontrol et
    if harf in sesli:
      sesli_sayisi += 1
    else:
      sessiz_sayisi += 1
print(f"sesli harf sayısı : {sesli_sayisi}")
print(f"sessiz harf sayısı : {sessiz_sayisi}")
# Out:
# Bir Kelime Giriniz :fsdfsdagfdhdlfşöhdf
# sesli harf sayısı : 2
# sessiz harf sayısı : 17
