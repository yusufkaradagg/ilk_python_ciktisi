# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/python_dersleri_2')
# !pwd
# Out:
# /content/drive/My Drive/python_dersleri_2

# %%
m = 17
if m > 5:
  print("m 5ten büyüktür")
# Out:
# m 5ten büyüktür

# %%
if m > 18:
  print("m 18den büyüktür")
else:
  print("m 18den büyük değildir")
# Out:
# m 18den büyük değildir

# %%
if m > 19:
  print("m 19'dan büyüktür")
elif m < 18:
  print("m 18 den küçüktür")
else:
  print("...")
# Out:
# m 18 den küçüktür

# %%
kod = 22
kod2 = 10
if kod > kod2:
  if kod > 25:
    print("kod 25'ten büyüktür")
  else:
      print("kod 25 ten büyük değildir")
else:
  print("kod2 koddan büyükür")
# Out:
# kod 25 ten büyük değildir

# %%
if kod > 15 and kod2> 15:
  print("kod ve kod 2 15'ten büyürktür")
else:
  print("kodlar 15 ten büyük değil")
# Out:
# kodlar 15 ten büyük değil

# %%
if kod > 10 or kod2 > 10:
  print("kodlardan biri 10dan büyüktür")
else:
  print("kodlardan biri veya ikisi de 10' dan büyük değildir")
# Out:
# kodlardan biri 10dan büyüktür

# %%
if not (kod > 24):
  print("kod 1o'dan büyürk değildir")
else:
  print("kod 10 dan büyüktür ")
# Out:
# kod 1o'dan büyürk değildir

# %%
print("notunuzu giriniz:")
notu = int(input())
if notu >= 85:
  print("A aldınız")
elif notu >= 70:
  print("B aldınız")
elif notu >= 60:
  print("C aldınız")
elif notu >= 50:
  print("D aldınız")
else:
  print("kaldınız")
# Out:
# notunuzu giriniz:
# 51
# D aldınız

# %%
yasi = int(input())
if yasi >= 18:
  print("yetişkin üyeliklerimizden faydalanabilirsiniz")
elif yasi >= 10:
  print("öğrenci üyeliklerimizden faydalanabilirsiniz")
else:
  print("çocuk üyeliklerimizden faydalanabilirsinzi")
# Out:
# 9
# çocuk üyeliklerimizden faydalanabilirsinzi

# %%
rakam = -5
if rakam > 0:
  print("rakam pozitiftir")
elif rakam < 0:
  print("rakam negatiftir")
else:
  print("rakam sıfırdır")
# Out:
# rakam negatiftir
