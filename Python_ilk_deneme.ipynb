# %% [markdown]
# python programlama dilinde print ekrana kullanıcıyı bilgi veren bir koddur.
# 06.08.2024 - Veri Yapıları Ve Algoritmaları dersi ilk kodlama dersi çıktısıdır
# İgü İSTKA SİBER AKADEMİ MERKEZİ-

# %%
print("merhaba") #ilk kod çıktısı
# Out:
# merhaba

# %%
import sys #import python programlama dilinde kütüphane eklemye yarayan bir kod bloğudur
print(sys.version)
# Out:
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]

# %%
from google.colab import drive # google colab - dirve bağlantısı
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/Veri_Yapıları_ISTKA')
# !pwd  # bize kodun çıktısını dosya yolu olarak veren kod bloğudur!!!
# Out:
# /content/drive/My Drive/Veri_Yapıları_ISTKA
